# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/English-Hindi code-mixed parallel corpus.csv')
data.head()
# Out:
#                                             Sentence  \
# 0  @someUSER congratulations on you celebrating b...
# 1  @LoKarDi_RT uske liye toh bahot kuch karna pad...
# 2  @slimswamy yehi to hum semjhane ki koshish kar...
# 3                    @DramebaazKudi cake kaha hai ??
# 4  @someUSER i'm in hawaii at the moment .  home ...
#
#                                  English_Translation
# 0  @some users congratulate you for celebrating B...
# 1  @Lokardi_ rat we should a lot more for that, b...
# 2  @Slimswami ehi, this is what i'm expecting you...
# 3         @Where is Dramebajakudi where is the cake?
# 4  @some user Don't want to come home next friday...

# %%
source_sentences = list(data['Sentence'])
source_sentences[:10]
# Out:
# ["@someUSER congratulations on you celebrating british kid singers sophia grace's and rosie's 1st anniversary of a visit of your show .  how",
#  '@LoKarDi_RT uske liye toh bahot kuch karna padega ye pappiyon se kaam nahi chalega #ForTheSakeOfHumanity',
#  '@slimswamy yehi to hum semjhane ki koshish kar rahe hain. Log to sab kuch ko issi mein tol dete hain. Context:http://www.opindia.com/2015/02/buzzfeed-editor-tries-to-make-political-tweets-you-wont-believe-what-happened-next/\xa0…',
#  '@DramebaazKudi cake kaha hai ??',
#  "@someUSER i'm in hawaii at the moment .  home next friday night .  don't want to come home .",
#  "Jeet ka jashn aur shubah ki shuruat â€” eating bread pakoda at Tandon's Cottage Vaishali Damoh https://t.co/ix2dB9b1Iv",
#  '1 sookha puri aur dena bhaiyapic.twitter.com/FvLEv3onxZ',
#  'Matlab tum Karishma nahin Raveena ho? Aur woh jo Karishma thi, woh ab kahan ravana hai? https://twitter.com/The_Karishma/status/499234729262997506?s=03\xa0…',
#  'Sachai ki jeet hogayi\n*aankho mein aansoo*',
#  '@Vyomnaut sahi me yaar']

# %%
target_sentences = list(data['English_Translation'])
target_sentences[:10]
# Out:
# ["@some users congratulate you for celebrating British kid singers Sophia Grace's and Rosie's 1st anniversary visit of your show",
#  '@Lokardi_ rat we should a lot more for that, by this evi people nothing will happen #ForTheSakeOfHumanity',
#  "@Slimswami ehi, this is what i'm expecting you to understand, people invest everything in this isnt it.",
#  '@Where is Dramebajakudi where is the cake?',
#  "@some user Don't want to come home next friday because I am in the Hawai at the moment  ",
#  "the celebration of a victory and the start of the day. eating bread pakoda at tandon's cottage vaishali damoh https://t.co/ix2dB9b1lv",
#  'brother could you please give me one more dry puri.Twitter.com/ Favlave 3xx',
#  'so that means you are karishma but not raveena? and where did the one with name of karishma go?  Http: //twitter.com/the_karishma/states/499234729262997506? S = 03…',
#  'truth won, and it lead to my happy tears.',
#  '@Vyomnaut right man']

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 45.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 85.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.0 tokenizers-0.13.2 transformers-4.26.1

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

article_hi = "संयुक्त राष्ट्र के प्रमुख का कहना है कि सीरिया में कोई सैन्य समाधान नहीं है"

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# translate Hindi to English
tokenizer.src_lang = "hi_IN"
encoded_hi = tokenizer(article_hi, return_tensors="pt")
generated_tokens = model.generate(
    **encoded_hi,
    forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"]
)
tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# Downloading (…)ncepiece.bpe.model";:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 200 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['The head of the United Nations says there is no military solution in Syria']

# %%
hinglish_list = list(data['Sentence'])

# %%
hinglish_list[0:10]
# Out:
# ["@someUSER congratulations on you celebrating british kid singers sophia grace's and rosie's 1st anniversary of a visit of your show .  how",
#  '@LoKarDi_RT uske liye toh bahot kuch karna padega ye pappiyon se kaam nahi chalega #ForTheSakeOfHumanity',
#  '@slimswamy yehi to hum semjhane ki koshish kar rahe hain. Log to sab kuch ko issi mein tol dete hain. Context:http://www.opindia.com/2015/02/buzzfeed-editor-tries-to-make-political-tweets-you-wont-believe-what-happened-next/\xa0…',
#  '@DramebaazKudi cake kaha hai ??',
#  "@someUSER i'm in hawaii at the moment .  home next friday night .  don't want to come home .",
#  "Jeet ka jashn aur shubah ki shuruat â€” eating bread pakoda at Tandon's Cottage Vaishali Damoh https://t.co/ix2dB9b1Iv",
#  '1 sookha puri aur dena bhaiyapic.twitter.com/FvLEv3onxZ',
#  'Matlab tum Karishma nahin Raveena ho? Aur woh jo Karishma thi, woh ab kahan ravana hai? https://twitter.com/The_Karishma/status/499234729262997506?s=03\xa0…',
#  'Sachai ki jeet hogayi\n*aankho mein aansoo*',
#  '@Vyomnaut sahi me yaar']

# %%
#ans_list = []
#for i in range(len(hinglish_list)):
#  sentence = hinglish_list[i]
#  encoded_hi = tokenizer(sentence, return_tensors="pt")
#  generated_tokens = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
#  ans = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
#  ans_list.append(ans)
#  print(ans)

# %%
#import pickle as pkl
#with open('/content/drive/MyDrive/810baseline1.pkl', 'wb') as f:
#    pkl.dump(ans_list)

# %%
import pickle as pkl
with open('/content/drive/MyDrive/810baseline1.pkl', 'rb') as f:
    ans_list = pkl.load(f)

# %%
ans_list
# Out:
# [["@ someUSER congratulations on you celebrating british kid singers sophia grace's and rosie's 1st anniversary of a visit of your show. how"],
#  ['# ForTheSakeOfHumanity'],
#  ['@slimswamy yehi to hum semjhane ki koshish kar rahe hain. Log to sab kuch ko issi mein tol dete hain. Context: http://www.opindia.com/2015/02/buzzfeed - editor - tries - to - make - political - tweets - you - wont - believe - what - happened - next /...'],
#  ['@ DramebaazKudi cake kaha hai?'],
#  ["@ someUSER I'm in Hawaii at the moment. home next friday night. don't want to come home."],
#  ["“Jeet ka jashn aur shubah ki shirat â€“ eating bread pakoda at Tandon's Cottage Vaishali Damoh https://t.co/ix2dB9b1Iv"],
#  ['1 sookha puri aur dena bhaiyapic.twitter.com / FvLEv3onxZ'],
#  ['Matlab tum Karishma nahin Raveena ho? Aur woh jo Karishma thi, woh ab kahan ravana hai? https://twitter.com/The_Karishma/status/499234729262997506?s=03...'],
#  ['Sachai ki jeetkhwayi *aankho mein aansoo *'],
#  ['Ignore'],
#  ['kaun hai ye zaleel insaan?'],
#  ['Haan, uske khidki khuli thi jismein se baburao jhaank raha tha.'],
#  ['yaar confess karte ho ya torture... itna bada bada confession'],
#  ['@ LoKarDi_RT'],
#  ['Miss u msd "aadat ho gayi hai aapko captain dhete hue. # Dhoni'],
#  ['Note ye application google playstore se download hogi, toh fake toh ho hi Nahi sakti "...'],
#  ['Bas Dhi ghamand Dhi Dhi Dhi'],
#  ['Ye bhasha kahan se sikha hai?'],
#  ['@dhaval241086 sure bhai :)'],
#  ['@ MohitParmarr ye kaun se channel par aur kab aata hai? Batao, zara hum Bhi toh dekhe!'],
#  ['"Agar Ayesi he baat hai toh peechley 15 saalo se bjp waaley congress ke Khilaf plaque \'prattyashi\' kyu khara kartey thein delhi vidhansabha election mein....?"'],
#  ['@ YouDontKnowWho_ Which _ Day?'],
#  ['Unhone pehle pic ni dkhi ti kya tmhari jo milne k bat hi ignore kia tmhe?'],
#  ['mai to itne games me b bas ninja turtles, street fighter, car race and mario khel kar khush tha baki games par dhyan dene ka tym kiske pas tha :-d'],
#  ['@ GantaGuy'],
#  ["Bahut log hai jo aapse baat karna chahte hai..plzzzzzz dn't brk thr hearts sir Plzzzz"],
#  ['ab voh bola jisne kisi Bhi party ko support karne se mana kardiya tha.. a flop show annaji'],
#  ['@ whycarewho kone wale plot me jagah zyada hoti hai :)'],
#  ['sala # Olympics k game bhare rehte the isme... dhokebaaz > _ <'],
#  ['Cha cha? ab seedha # Trump nazar aane laga? Kasab se Trump tak?'],
#  ['Bahot time Bav suna ye! Achha laga'],
#  ['kuch Nahi samjha Kabhi, itne saare cheezon se deal karna aata toh shayad life mein succesfull hota.'],
#  ['@iamGunjanGrunge Tharak saale har ladki ko mention karna hai zväče @brawling_virago @Atheist_Krishna'],
#  ['@ thisisAparajita sahi hai :('],
#  ["Today's match"],
#  ['You have to be able to read it in your own language.'],
#  ['Your emails'],
#  ['@ mamtan14 didi abhi bhai me time hai'],
#  ['Abe Congressiyon, Nigerians Bhi insaan hote hain, bandar nahin. Kyon itna bura maan gaye.'],
#  ['oct 30 its goin down at the congress theater i will be performing along wit machine gun kelly!!! http / URL'],
#  ['kitne dukh ki baat hai na :('],
#  ['# TripleTalaq ho ya Divorce usshme koi matvate / Rajnetic Na honagadh. Mahilayo ke ke ke hÉireann sharaph ke saman hi hai. Triple Talaq ko roke.'],
#  ['What are you doing? What are you doing?'],
#  ['Wâ€¦ise tu boli nai ki hai kaha se'],
#  ['luncher paaji pehle chai k saath biscuit kha rahe the..'],
#  ['@ anchalator toh dhe theek hai, aise kisi Ladki ke T - shirt mein kuch Bhi kaise daal sakta hai koi?'],
#  ['@ twinitisha dhe to twitter walon ki khush - naseebi hai :)'],
#  ['Happy Birthday Dhoni & Hello to Sakshi bhabhi. Aur baaki sab khairiyat?'],
#  ['LOL, phenk deta to bechare ka Phir kat jaata bill, isiliye lauta diya chup chaap. # EkBhaiKeLiye'],
#  ['Did Arun Lal say, "Ye dheiye Bangladeshi player khushi se apne andkosh takra rahe hain"'],
#  ["It's the first time I' ve watched a movie on Sony TV. It' s the first time I've watched a movie on Sony TV."],
#  ['@ Atheist_Krishna bhai bas kya hamesha Sunny Leone dikhau..'],
#  ['@narendramodi have students in your country? #gst laga diya hai bas kuch socha tha pehle?'],
#  ['@ Gott_Partikel aankh band karte hi shruti hassan nazar aati hai :('],
#  ['@pandyas0599 Gud mrng sir aapko Mahashivratri ki hardik mangalkamnaye :)'],
#  ["amazing day today. i can't wait for tomorrow"],
#  ['Sorry, we are late at 11.30.'],
#  ['Phone: wallpaper: wallpaper: wallpaper.'],
#  ['@ @sayshardik @pintubaba_ Ye baatli fəaliyyət fəaliyyət :('],
#  ['# NoteBandi mein Temporary Ban to lag Chuka hai 0 Koi baat nahin hai!'],
#  ['"Too oh oh achhi baat hai Nahi, mitthaiyan khilao!"'],
#  ['OMG kisi ne RT spree diya saalo bath.. Thanks @ SahiDisha *khushi ke aansu*pic.twitter.com / P75DZ5jPkk'],
#  ['Brilliant Answer By Boy Friend on Break Up. Girl'],
#  ['@ RanaAyyub ye Amit bhai ne Nahi Muhammad Ali ne kaha tha pagli'],
#  ['Please follow @ SaleemChikna & @sayshardik, ye log free mein daaru pilaate hai. # AiShappath'],
#  ['@ Perrignrr ye kya hai?'],
#  ['Haar aur Jeet to khel ka hissa hai.'],
#  ['@Kahaanify bashti wahan doobi jahan paani kam tha'],
#  ['@ Sagarcasm abhi Bhi hu'],
#  ['@ BeingMSD mera motive kuch aur tha'],
#  ['err @ DefucktiveHumor ye le ek aur'],
#  ['My Guru ji ko pehchanne se inkar karne wale logon ko Pakistani visa ke Sath passport muft diya jaaye. Pranam.'],
#  ['Yaar, koi ye bata do ke yeh ladki hai kaun? https://twitter.com/Sarcaism_ / status/733178336147562496...'],
#  ['Your emails'],
#  ['_ / _ SIR. Rulaoge kya?'],
#  ['Your emails'],
#  ['ultimate yarrr... just love it'],
#  ['@narendramodi ISI to vote according to'],
#  ['Bas aise hi reviews ki zaroorat hai, kaafi protsahan milta hai in baaton se.'],
#  ['@ akshaykanitkar Sahi hai, bada aadmi hai tu. Kya chal raha hai? Kab milna?'],
#  ['https://twitter.com/BolshoyBooze/status/595267739297587200... @ Dukhi_Engineer'],
#  ['Salmannnnn aaa intezaar idhar? tere produce?'],
#  ['@ PratMitt @ GabbarSingh'],
#  ['@ Bunlimted hahaha.. Bhai'],
#  ['You have to base your sahara on the following:'],
#  ['@nickhunterr hahaa..'],
#  ['@ Bihar_ke_lala khusi hui tumhara janamdin aaya'],
#  ['Use to gate se bahar hote hi utarna compulsory tha'],
#  ['kahi rajnikant to nhi tha'],
#  ['@sureshnakhua'],
#  ['Keerthi! Lets open a NGO together!'],
#  ['India kbhi Bhi china ko peeeche nhi kr paaega.....'],
#  ['That Spin! Ravi Ashwin. Kuch nai ho sakta bhai Africa ka World Cups mei. #Mauka #IndvsSA #cwc15'],
#  ['t. v. off guddu: mummy.... khane me kya hai'],
#  ['chalk churane ka Bhi plaque maza tha... :)'],
#  ['ji bilkul, iss baat ka toh inkaar Nahi karhesh.'],
#  ['Sabko bacha kaho, sirf mere ilawa ok'],
#  ['@ sahilmjain ek Nahi mili ab tak / 3'],
#  ['@ Baby_ Bhaya Bhi dena zara 5 rs ke.. Bhookh lagi hai'],
#  ['.....'],
#  ['Everyone on TL is thanking their Moms. Bhai aiyaashi karne ke paise to Papa hi dete hai na.. #ThankYouPapa'],
#  ['@iamGunjanGrunge Tanmay jail ko hi kha jata'],
#  ['Shakti bechara Kabhi kuch bolta Nahi hai, he is like a husband eve n before marriage.'],
#  ['Phone Dhane mein taqleef hai kya?'],
#  ['@ balliawalebaba bas badiya sab.. Upar wale ka sahara hai.. Abhi chai pee rahe hai :)'],
#  ['@ rsairajeswari Zamana kharaab hai.. Shine lajawaab hai: https://www.youtube.com/watch?v=CK4rf9T6OrI... # LagGayiVaat Shine'],
#  ['Hello saadu saahab (senior bro in law), ki haal chaal?'],
#  ['jabatdast dost.... 1 page me rula diya yaar.... kamaal hai.... superb nd hatss off to ur createivity...'],
#  ['@ MissKhushiSen'],
#  ['Salman Khan kaha ho?'],
#  ['% 1 square days'],
#  ['atleast jise thand lagti ho use de dia karo :)'],
#  ['Hiii sir, aapse milne kaa sirf ek maaukaa chaahtaa hu.....'],
#  ['... abhi aayega rukiye " @mehrishisumati : Once upon a time there was a hashtag #RailBudget2015 "'],
#  ['@ Ojasism bhai aajkal sab ke paas 4 - 4 car hai..'],
#  ['Today Indrani ka kitne opponent patiyo ka pata chala.. Koi update karega?'],
#  ['@ loveOKplease kuch Nahi, ek tweet padh ke gussa aa gaya: /'],
#  ['cheapest Nahi pucha. Best pucha hai.'],
#  ['YE DEKH LO DUNIYA WALO.. https://twitter.com/Winkerbell_ / status/661805356947927040...'],
#  ['Az kal yeh hi bikta hai bhai!'],
#  ['Dhoni bhai ek din ball tod hi denge!'],
#  ['Bhai kuch kal ke hÉireann bhi chhod de.. RT @ EconomicTimes # KajriwalTakesOath: I hope that India wins the World Cup'],
#  ['missing dat tym... happy new year all...'],
#  ['i love my girl evelyn at work she switched shifts with me saturday:)'],
#  ['Hi Congress, today do we have Rajiv Gandhi Janma Diwas Sabko Daru Free Party Yojana?'],
#  ['sooo creative.. u guys r awsummm. :)'],
#  ['Bahot hi undaa! https://twitter.com/Madan_Chikna/status/654533563803660289...'],
#  ['@ Alllahdin Ye Bhr! pic.twitter.com/mf0QwulkQe'],
#  ["@ MirrorCracklin הי toh Nahi aaya phone: '("],
#  ['Rahul Gandhi kuch Bhi kar le, log use Pappu hi samjhenge.'],
#  ['Aj ya #windies larkia leke jaegi ya boys.. :) #WT20 #WIvENG #AusWvWIW #WT20Final'],
#  ['@ Dipti1104 bold hain aap'],
#  ['RT @hraddhaKapoor : Cine stars ki khoj in #Atsu & #Zara! #Haider #2ndOct @tanya1ghavri http://t.co/BznIyUfZ9d'],
#  ['Chain ik pal Nahi " aur koi hal Nahi " #Jio ni ~ Other operators 0'],
#  ["how do y'all feel about moving presidents day to august? august lacks a three day weekend. then make lincoln's b - day a day off too. # boom"],
#  ['@ SirBachchan sir aap badal gaye ho. Aajkal milte hi Nahi ho. Kitna waittiae aapka ghar ke bahar'],
#  ['@ Akshaykanitkar @ Ra_Bies @ Oinkoo Sunil, tu aur main'],
#  ['@ tweetofdeb'],
#  ['aur free wifi Bhi wahi hai. Lol'],
#  ['@ AksharPathak jokeya.... accha'],
#  ['guddu k papa toh emotional ho gye'],
#  ['@ Vipul_tweets_ kya yaar, sarcasm Nahi samajhte @ vivanair @ Zahriano'],
#  ["Tu hai meri kiran' ~Me, to sunshine"],
#  ['"Mhari chhoriyan chhoron se kam hain ke?" https://twitter.com/timesofindia/status/813728641943293953...'],
#  ['@ Bunlimted Baby holiday Gabbar jaisi awesome movies akki hi kar sakta hai.. # WeLoveAkshay @ aamir_nation @ aamir_airlift @ aamir_khan'],
#  ['RG: Mom, budget budget khelna hai Mom: Beta, tumhare women empowerment khelneke din hai RG: yaay! ringa ringa roses # RahulOnLeave'],
#  ['Your emails will not be published until this date'],
#  ['@ chatpatidiary'],
#  ['@Babu_Bhaiyaa @KyaUkhaadLega'],
#  ['. @ SRKswarrior1'],
#  ['Kaahe jaage ho be?'],
#  ['@huh_watnow chee chee gandi baatein'],
#  ['# GuessTheSong Bade dhoke hai iss raah mein'],
#  ['Aise aa rahi hai Bihaar me Bahaar # NitishKaAgentPratyayaAmrithttps://twitter.com/Bihar_ke_lala/status/660750933270245377...'],
#  ['@ Atheist_Krishna'],
#  ['@iamkits haan Bhai aur hot Bhi - D'],
#  ['See if you can connect to your local area.'],
#  ['@ MeetUunngLee Nahi bhai mere tweets par log rote hai'],
#  ['"Main aaj Bhi pheki huee Ball nahin uthata" ~ Umar Akmal # TwistedBollywoodDialogues'],
#  ['. @ Arpita_ joshi13 @ e29ad41b95b341d sirf tumhare hÉireann, chhodo ye sab hate. Aao dhe ki baatein karein DM par. Ok?'],
#  ['@ theamarjeet Haan bhai Ayesha ke sab fan hai'],
#  ['Journo: Laluji, monkey 11 bacche kyon paida kiye? Lalu: Kyonki uske bath hum thak gaye thay.'],
#  ['"Aisa na hua hota agar aapne Modi ko PM na banaya hota" - Shri Kejriwalhttps://twitter.com/nypost/status/718203194556432384...'],
#  ['Kal kaam par tumhare abba jayenge? So jao.'],
#  ['@ CelkonMobile # CelkonCheers4India Oye Balle Balle 1 aur Four http://t.co/dCvJmecLqr'],
#  ['Sab khana kha ke daru pee chale gaye..'],
#  ['mast hai.. mona bhi dekha karo.. daru ki essentialat Nahi padti'],
#  ['@ Ra_ Bies Thodi si jo pee li hai.. chori to Nahi ki hai..'],
#  ['kya sir? Achha tha bhai'],
#  ['@ DrDhimantPurohi ha ha ha, santa inka naam Bhi note kar lein :)'],
#  ['# FarziPatrakarRavishKumar'],
#  ['Sir me apka big big fan hu mujy apse call pe bt karni hai ek bar sir mera contact num 03356507139 Skype I.d abdul.rehman6731 Plzzzz contact meabdul.rehman.sahabto'],
#  ['Your emails will not be published.'],
#  ['Entertainment is free of charge in all areas of the country * wipes a tear *'],
#  ['Settings Show Statusbar'],
#  ['Aa gaya mauka... India won.. # IndvsSA'],
#  ['@ Champ_ Nikk bilkul sahi.. Bihar may achhe din toh aaney he they # GoodByeNitishKumar'],
#  ['bibi wants to use our military for free.'],
#  ['# SamajwadiParty se # Gathbandhan to kar liya unhone....'],
#  ['Jor se poetry lagi hai.'],
#  ['tu teen baar talak bol dena'],
#  ['Jin logon ko FAN ke bina neend Nahi aati woh movie zaroor dekhein, isse unhe neend aajayegi.'],
#  ['Today naked,kal udhaar. # MainBhiPunDit'],
#  ['Your emails'],
#  ['kahin tu whi tom boy type ladki to nhi jiske bare me kal ek ladke ne confession post kia tha????????????????????? lol'],
#  ['She wants to see my ration card.. Apne ghar se Bajrangi Bhaijaan ko bheja tha.. Bhool gayee https://twitter.com/MehrTarar/status/633331132810043392...'],
#  ['_Sleigher ANGREZO BHARAT CHHODO'],
#  ['Delete kar dia'],
#  ['" #lol... #Ireland ye to tumhaari batting ka #Pakistan ho gaya #CWC15 #INDvsIRE"'],
#  ['to https://twitter.com/gauravyoo/status/801016899811282944...'],
#  ['Jalne walo jalte raho.. Modi ji aap aage badho.. #ModiInDubai'],
#  ['@ Swt_Sadhana lets hope.. Muhe to umeed kam hai @ BJP4India @ ANI_news'],
#  ['@ BolshoyBooze: - - O'],
#  ['@ MaryaamShakeel Aaj to # kohli tum logo ko akele pela hai, socho zara jb 125 crore log pelenge tab kyakhwa..? # IndvsPak'],
#  ['@sayshardik phone'],
#  ['@ oxymoronic_ me mat karo dhe, kyun barbaad hona hai? < / 3'],
#  ['Sir Hamare ghar me white wash ho rhi thi. isliye copy ghar pe reh gayi: - d'],
#  ['RT @ Ssaniya25:'],
#  ['. @ HarshJ12 plaque kam khud karo.'],
#  ["he's my dad but.. hum unhe pura match Kabhi nhi Τne dete.. it's a pretty big feat.. lol"],
#  ['Ankit LOL and Arnab ko Modi ka kutta bola. shaam ko maza http: / / aayega.lol'],
#  ['Modi ji.....ye galat baat hai jo aapn 3 crore ka stage lagwa raha han..... please think about it'],
#  ['@singhlicious twitter kam ho gaya hai :)'],
#  ['RT @ 101santosh1 : @ MUKESH42957410 @ PandaJay PRABHU KEY GHAR MIE DER PR ANDHAER NAHI YEAH SATYA H'],
#  ['I am a mil gaya haii...'],
#  ['This is a list of the languages spoken by Samaritans.'],
#  ['miranda house ka bi page hona chahie ab to :-d :-p'],
#  ['Mishra ji ise haathi bol kar haathi jaise achche jeevo ko gaaliya na de @nikhil__13 @Ra_Bies'],
#  ['Your emails'],
#  ['@ hennarendra aajkal hum khud hi ghom rehte hai.. Ladki chhod ke chali gayee. Dil hi toot k reh gaya hai'],
#  ['Apna phone number dijiye.. Abhi doubt door kiye dete hai'],
#  ['hahaha very nice maine Bhi kai bartiae h.'],
#  ["RT @ s_ navroop : AC EMU MILI NA!!! @ HeadlinesToday : Suresh Prabhu's # RailBudget2015 disappoints Shiv Sena as'Maharashtra didn' t get anythi"],
#  ['Yes Aero totally rocks'],
#  ['Gloantra divas ke laddu wah bhai kya baat kya baat kya baat...'],
#  ['meri purani hai'],
#  ['Dil aur DMaag hamesha khule hone hÉireann.'],
#  ['@ Atheist_Krishna aur agar aaj koi kuch bola to "bura na mano holi hai" @ Bhaiyyajispeaks'],
#  ['Ab @ ArvindKejriwal plaque Janlokpal ka vaada kab poora kar rahe hai?'],
#  ['@ CescyJose mere sapnon ki Rani kab aayegi tu'],
#  ['300'],
#  ['same here bassss 20 ki jageh 5 milte the maa se.... :)'],
#  ['My to Bhopal me hi kha raha'],
#  ['@ GreySasquatch lol! Haar gaye?'],
#  ['RT @ CayriTrolls: Modi ji, aapne kisi aur ko exam likhne bheja dhe. Syllabus se kuch sawaal mein poonchu toh ans de paaoge monkey? Bolo bolo.'],
#  ['RT @ fanthegame : Vo sirf STAR Nahi hai, दुनिया hai meri! Watch trailer https://t.co/8iFTZvjYPe # KheloFansKhelo @ FanTheFilm @ yrf https://t.â€¦'],
#  ['Subah thatez hi aisi hai, that raat pasand hai'],
#  ['RT @bhavanakumari9:'],
#  ['Bhai guddu.. kamaal kardi yr.. apne bhai pe gya h tu bilkul.'],
#  ['Aakaash : Oh Boy, Jason Roy... Jason Roy : Aakaah ChupRe.. # ENGvNZ'],
#  ['kuch garam ya thanda khane se agar daanton me tez jhanjhanahat ho, to use sensitivity kahte hain...'],
#  ['RT @ sudirchaudhary: Good to see Manoj Kumar at the centrestage once agn!'],
#  ['Petrol prices hike kya koi Bhi virodh karne wala Nahi bacha @ thewirehindi @PatrikaNews @ravishndtv #petrolPrice #GST'],
#  ['kya kre maa ka payar h pagle: p'],
#  ['i need to get ready for the 6th district chicago police rally against violence. chi - town cheer will be performing. king dr.'],
#  ['@huh_watnow kitni baar Bhi bhejo kam hai @twinitisha'],
#  ['@ Heerahee tu mahan hai'],
#  ['Mom: Why are you listening to plies early sunday morning? me: * blank stare * * pause * my strip club name is mr. will - throw - it * walks away *'],
#  ['@ MeetUunngLee bhai'],
#  ['@ Aniket_bhau @ AniketRanade'],
#  ['RawdyTalks'],
#  ['Aap bhi bohot handsome lag rahe the aur baachhi bhi bohot cute thi. Charming song. Mazza aa gayi thi. :) :) :)'],
#  ['Kejriwal: Time kya hua hai? Ashutosh: Sir 12:30 / 1 Kejriwal: Kya bola, sahi se bol. Ashutosh: Ab ho gaye 12:31 / 1.'],
#  ['@ Dhavalkate soch., achhi baatein karni hi nani'],
#  ['RightToPrivacy par @JhaSanjay @mukeshtiwariji @DwaipayanM'],
#  ['temple run --> an endless run for money gud one :)'],
#  ['Relationship status: where kya hota hai?'],
#  ['Aur is baar jo proof maange "chahe wo khi ka # CM hi q na ho "seedha # Goli _ maar _ do _ unko _ V'],
#  ['@ Indiantweeter'],
#  ['aj apne hum sbko bht hurt kiye salman... apse ye umid nhi thi hum sb ko :-(...bt m also luv u salman...:)'],
#  ['Hitendra Katiyar Saharsha Keshkar Sanket Rathi Akhil Sharma Manish Chalana... Bihari Bengali h kya?'],
#  ["I'm sorry, you' re having a bad day and you're having a bad mood."],
#  ['@ KyaUkhaad'],
#  ['#LiesMenTell Woh pareshaan karte rahe, hum kaam karte rahe - Kejru'],
#  ['Sometimes bharat k 1 karode #santramplji k anuyayaidhn k man ki Bhi suno jo 681 din se nyaya mang rahe h # ProteinPledge # CriminalAAP # Trump'],
#  ['Paisa kya hai, aaj hai kal Nahi, parso hai - Baburao Ganpatrao Apte'],
#  ['faisal bhai.... itna... kyu lagate ho apne fans se mukhatib hone mein..'],
#  ['guddu tri series aur test series mein, kya lene gya tha?'],
#  ['Trump banne ki koshish.. matlab ab yugpurush ji US Prez ka chunaav ladenge?? God save America @ angryoungwoman'],
#  ['Radical'],
#  ['Kitthe reh gaye sallu ji 04:07 ho gye'],
#  ['@ ExSecular to mehenga wala maal mangwaya hai'],
#  ['Hasee toh Bhi Nahi phasee.'],
#  ['RT @ ImVKohlisAngel : @ RainaKiGudia Awwwww cutuuuuu.... Thankuuuu love... Good night'],
#  ['Dhoni should remind Faf abt IPL!! Agar khelna hai toh out ho jaa!! Hussey z back in d team!!! #justsaying #IndiaVsSouthAfrica'],
#  ['Send _ In _ Day'],
#  ['@ Pluuummm'],
#  ['@ village_wale oye Shashi sabudana khichdi hai. See prooerly'],
#  ['iss @ LoKarDi_RT se compliment? Sigh.'],
#  ['i think wearing weird clothes and chappals mean we are innocent.train us with your own risk: d'],
#  ['Tu odd pe Karan Johar ke saath aur even pe Bobby Darling ke saath soya karhttps://twitter.com/Atheist_Krishna/status/682871268610191361'],
#  ["bay area heads! i'll be on the piano at yoshi's san fran this sunday playing with the one n only dwight trible - http / URL"],
#  ['@ sawlanis2 Gunda raj aur jungle raj dono samapti ki or hai.. Bus dhete jao # BJPAheadMGBDead'],
#  ['@zoomphatak iss baar thoda zyada easy ho gaya'],
#  ['Pyr Bhi paap Nahi 4enge tere Kaju https://twitter.com/KajuBadamChor/status/756433421576970240'],
#  ['Kejri Yogendra se pareshan. Modi Yogi se pareshan. Musalman Yoga se pareshan.'],
#  ['Fan: Jai Shree Ram Anupam Kher: Jai Shree Ram Fan: Om Jai Jagdish Anupam Kher: y u do dis to me :('],
#  ['@ Atheist_Krishna ye saare paise Rakh le aur meri suhaagraat pe national anthem mat bajanapic.twitter.com/Pg46hCOq4l'],
#  ['@ supaarwoman Chhod na.. Itni si baat ke hÉireann ki naukari mat cheen @ishaan21'],
#  ['@ Ibleed_sarcasm'],
#  ['@ ashutosh83B'],
#  ["@ someUSER c'mon guys fix this please, i dont want this to end up how diablo iii did.......:"],
#  ['Haha, awaaz zyada badi aati hai. Na?'],
#  ['Your emails'],
#  ['# ModiKaBudget #Budget2015 #Indianbudget #SuperBudget 5 ultra major power projects http://t.co/4Qg5JfmqYN'],
#  ['Chacha jaan ye biwi hai keema paav Nahi.pic.twitter.com/KTTMl4kZaS'],
#  ['Phir toh Swiss bank me kitna Paisa Hai wo Bhi # RightToPrivacy'],
#  ['Happy Mahashivratri folks :). Har Har Bole. Om Namah Shivay'],
#  ['nothing equivalent to moms.'],
#  ['@ Rialisticme ek bechare ladke ki khushi Nahi dekhi jaati tumse'],
#  ['ladka gaming mai khoya hua hai....'],
#  ['PIB_India #UHF RT airnewsalerts : RT MIB_India FAQs on #RailBudget2015 - Procedure of approval of Rail Budget by Pa http://t.co/aU6k1nt9VG'],
#  ['@ tweettabulous yaar man ki hi toh baat ki thi! LOL'],
#  ["Isse lag raha hai main ladki hu. Aise DM's aate hai.pic.twitter.com / qIEfUNmtwL"],
#  ['@ DefucktiveHumor abhi itna darr Gaye hai ke rally Rok rahe hai.. Par kya fayda? # NitishKaChehraDiveshSehra'],
#  ['Bhai koi iske tweet copy karo.. Ye khud ke tweet copy kiye jaa raha hai.. Koi RT Bhi Nahi karta pic.twitter.com/sUyah8zReK'],
#  ['@ akshaykanitkar Nahi bhai Gujarat@ BabaBakChod'],
#  ['@ FarhanKVirk sharjeel Motey kaddu ms talent Bhi Nahi hai'],
#  ['When Sagarika was born doctor said "Mubarak ho aur Shubhkamnayen Bhi"'],
#  ['Kis Kisko Pyaar Karoon - Official Trailer - Kapil Sharma, Arbaaz Khan, Eli Avram & Manjari Phadnis http://t.co/XDhFJyi8jQ'],
#  ['Are beimano # SurgicalStrike pe tumhi log Pakistan ki tarah evidence mang rahe thena??? Tumhara Fake Emotion sab Hindustani jan chuke he ab!'],
#  ['bb will be huge blockbuster. aap jiyo hajaro saal.'],
#  ["Tum chahte hoΙΝ par police case ho jaaye < \\3 : '("],
#  ['@ itsmanimozhian mar ja bhai'],
#  ["nikon has once again proven it's a small world after all with the latest... - herald sun http / URL"],
#  ['# ZarooratHai ab saare'],
#  ['@ Bhaiyyajispeaks Kya baat hai, maine Bhi koshish ki this Shraddha Kapoor ki photo banana ke hÉireann magar Jadoo jaise ban gayi kuch.'],
#  ['Mere ghar ke paas me hai'],
#  ['@ DrShobha Maam mausam achcha hai.. To socha ghoomne jaane se pehle pooch lu@ BDUTT @ ChouhanShivraj'],
#  ['@ someUSER @ someUSER nooooooooo!!!!!! maybe you can just look over it right before the test tomorrow and do that first'],
#  ['@ Ojasism bhai so ja'],
#  ['@vikrantkumar ye baat to hai.'],
#  ["Rahul Gandhi is rich man's Tejaswi Yadav."],
#  ['@ toastingtoaster Bhai ne driver ko terror dia'],
#  ['shaan is like.. question kahin mog par na aajaye: p'],
#  ['RT @ helloanand : Brilliant answer by Dhoni when a media guy asked about his retirement - https://t.co/irgS0ieIex'],
#  ['Okay, done! Usko Bhi make up lagana, ok?'],
#  ['@ barkhasbutt'],
#  ['Shoaib Akhtar to @ SirBachchan, sir aap jawani mai cricket khele hai, to aap bowler the ya batsman @ msarosh # IndvsPak'],
#  ['@ LEDtvn adhi உலகம் ko to dikha chuki ho'],
#  ['Tum הי varghani do, main tumhe paavti dunga.'],
#  ['This is fake news shame on you media usa how much given you money blady media.......'],
#  ['usse dikkat Nahi.. dikkat dikhawa ka hai'],
#  ['RT @ The_ Bapu7 : Virat Kohli Warming Up! Whoaaaaaa Pehli Baar Accha Lag Raha Hai Use Dekhke'],
#  ['4 baj gaye.....par party aabhi Baaki he....sallu bhai'],
#  ['What do you think of DP to follow? Khiyaa Aur usne tumhe disappoint במה? Khiyaa..'],
#  ['#FailedCMNitish'],
#  ['@ twinitisha maine to Nahi lagayee'],
#  ['@ friendlii_ ghost okay sir. Hamare Bhi din aayenge'],
#  ['Kal Bhi paani Nahi aaya tha waise! # Budget2016https://twitter.com/ArvindKejriwal/status/704247260461150208'],
#  ['@ SharyAhmad19. Fazool batein kr rahi hai'],
#  ['@ HiighBeta Chal ghoomne mere saath.. In my car..'],
#  ['@ Shockraborty Mummy ape hamesha הי daant lagati ho :( beta tum ghar ke bade ho na'],
#  ['@ dan1shmemon bhai theek se padh kya likha hai Plz'],
#  ['say no to dummies jinke pass khud ka dimaag Nahi dusro k kahne par chalte hai'],
#  ['true!! joke haiÃ°Ã ̧œâ€šÃ°Ã ̧œâ€šÃ°Å ̧œâ€š accha maazak hai @rajabetasharad https://t.co/F6RCbgnkBm'],
#  ['@iamsonisinghal Dhaniye ki chatni me namak kam reh gaya'],
#  ['Bhai angreji batao na kuch.. kuch samaj ni aa raha'],
#  ['"Na bhai na, aise thodi hota hai, ye aate time Bhi window seat pe baitha tha" #AUSvPAKpic.twitter.com / PpTsXLrl1b'],
#  ['When Sagarika was born doctor said "Mubarak ho aur Shubhkamnayen Bhi"'],
#  ['" munh khol ke 20 rupay mang הי... "oh i love this line.'],
#  ['Bhi peeni hai < / 3 @sinezero'],
#  ['Sab anti national hai saale.'],
#  ['Khawaja Mere Khawaja chal wapas chale jaa #IndvsAus'],
#  ['% 1 is already in use'],
#  ['Sonnami hai tumko? Subah uthna hai na jaldi? Sleep'],
#  ['@ kamaalrkhan sir ye tweet unko bhej do. Itni Hi - Fi English padh ke wo waise hi suicide kar lega.'],
#  ['Kya lifetime like hi karogi? Kabhi RT Nahi karogi?'],
#  ['"Bhaiya Goal ki taraf le lo" Autoguy: "Us taraf Nahi jayega"pic.twitter.com / S8MqgLf25i'],
#  ['. @ ashutosh83B to Phir rishta pakka samjhen?'],
#  ['RT @ruchikokcha: @Atheist_Krishna Isiliye ( sadly ) I am perhaps the only woman jisey Kohli ko khelta dhe bhai wali feeling aati hai.'],
#  ['tu such mein pagal ho gai hai......jo ho gya so ho gya babu....ek achhi and happy life start kar....'],
#  ['Gangaa ka shiraj tu Himalay ka seena hai. Sone chaandi se Bhi keemti. tera ye paseena hai! Come back Maahiyaa #Dhoni'],
#  ['Thank God they didn \'t end up with "Dekhna na bhooliye Ae Dil Hai Mushkil bhai nasdeeki cinema gharon mein. # MadeByGoogle'],
#  ['( jab tak dhoni hai atleast main to chipka rahunga..:)'],
#  ['ye @ AapGhumaKeLeLo aur @ AndColorPockeT alag level hai bhai, wahan Nahi pahonch sakta koi'],
#  ['Tumhare chashme ka number hai kya?'],
#  ['Isko bhav mat de.. ye Nahi dene wali'],
#  ['You are about to leave a message. Do you want to delete it anyway?'],
#  ['@kkundra lol ladki mil gyi. Martina here you go girl. hahha shit #Roadies'],
#  ['"Aaj mein bohot khush hu.. pehli baar sau ka note dikhaya bhaijaan ne.. "'],
#  ['TERA PEECHA NA MAIN CHHODINGA SONIYE, BHEJ DE CHAHE JAIL MEIN PYAR KE ISS KHEL MEIN *shakes head like Dev Anand *'],
#  ['@ jaikesarinandan'],
#  ['A small farmer in Mahoba " #UttarPradesh : matar 6 rs kilo bech raha hun #notebandi ke kaaran! Ab chunaav me shirenge inko 0'],
#  ["Today's Jitne Bhi teaser trailer"],
#  ['@ Tweepshikha meri achhai ka toh benefit utha rahe ho tum, mazaak udaa kar. @ Tweepshikha meri achhai ka toh benefit utha rahe ho tum, mazaak udaa kar. @ Tweepshikha meri achhai ka toh benefit'],
#  ['Ye sarasar na insaafi hai Chikna bhai'],
#  ['@ KyaUkhaadLega hahaha. Khana khaney to get Plato ka bandobast Bhi kar lena.'],
#  ['@ friendlii_ ghost haha, sab karte hai'],
#  ['main scooter ke aage khadi hoti thi... to papa samne dhe nhi pate the.. hehe'],
#  ['hey bhagwan...yeh movies bachcho ka satyanash kar rahi hain..: - o : o'],
#  ['@ Lambar_Daar haha bhai subah se idhar udhar ho raha hu @ MAKKARROMA'],
#  ['RT @ coolfunnytshirt : Maine daant tod dena hai Arnab ke agar aur kisi ka resignation maanga toh!!! http://t.co/OuPkhWLllf'],
#  ['@ friendlii_ghost kuch Nahi bhai, sab emo chep rahe hai'],
#  ['@ akshaykanitkar HAHAHA. yaar kya karu. Hasne wali baat Bhi hai'],
#  ['@ KyaUkhaadLega Main Arvind Kejriwal HU, Plz phone uthaiyega'],
#  ['@ samy3010 yeh galat iljham hai'],
#  ['Do you really want to delete this message?'],
#  ['Dhoka Nahi, Dhokla khao.'],
#  ['@badrirag @ArvindKejriwal'],
#  ['Rasha Sindh is not a property of Pakistan.'],
#  ['Mall me saari ladkiyan achchi lagti hai # GuyFacts'],
#  ['har cheez ka galat matlab nikal kar ye, galat хоног smmileys bhejti hai. Bahar se sanskaari andar se Dhuandhari.'],
#  ['# GuessTheSong Tu jo dariya mein utre saara paani gulaabi'],
#  ['It is one of the best gigs of grbg bin i hv evr encontrd.... smply owsm.....'],
#  ['great ak sir. aap zindabad. we have to first ensure on evm machines because these people are filthy'],
#  ["it's wednesday!! you know what that means.... new episodes of the challenge: battle of the seasons &amp"],
#  ['Your emails'],
#  ['Bhai aap bhul gye kya hume social science kisne jayegi h, unhone dekha to pitaayi ho jayegi.'],
#  ["@ shubhansh1504 jab koi bahana Nahi hota to bolte hai'server down hai'"],
#  ['Diwali Shopping wahan se karo jahan kisi gareeb ki Diwali achi hojaye #Diwali #deepavali'],
#  ['Bajrangi bhaijaan mein koi aisa scene jo yadgaar ho????'],
#  ['@ Anoushey_a pak out ho chuka hai r kiwi se jeetna namomkin'],
#  ['haha, Nahi dekha yaar. Hai link?'],
#  ['@vikaspgoel @ c_ aashish RT ki mohmaaya main na padein. Validation to get shabd hi kaafi hain.'],
#  ['logo ko ullu banana wale ko solid reply'],
#  ['"Tumhara Pritam Pyaare aagaya ho toh hum sone chale jaaye?"'],
#  ['@ scratchysingh main ek nek aur shareef bachha hu'],
#  ['He is innocent otherwise like # kanhaiya, poor student of # JNU'],
#  ['Shukriya Bhaijaaaaan... Mere bday pe aj tak mila huva Sabse... Bajrangi Bhaijaaaaan....'],
#  ['@ Dishasatra LOL @ PJ_CRACKER @ ROFLaaLa Lala bhi Bhi Bhi behen bana le please'],
#  ['Desh ka yuva jaag chuka hai, yuvika ka kya?'],
#  ['# TripleTalaq judgement to bat!'],
#  ['I_m_nat_war abla naari ki help kar'],
#  ['Election commission ko Bhi @ BJP4India par najar Rakhni. Gujarat Haath se jaata Dekh ab # GST yaad aa gaya inhe'],
#  ["Bahot hi galat הי ya, shraddhanjali arpit karte hai: '("],
#  ['RT @ SRKswarrior1 : Arre yaar Dhoni 59 ball mein outkhwaya Akkian - accha hua! 59 ball mein 29 run banaayeAgar 106 ball khelta to sirf 16-Ã¢â‚¬Â¦'],
#  ['@ indiantweeter wahi hota hai jo manzoor - e -khuda hota hai.'],
#  ['@iamGunjanGrunge MaPoSe murder sorry kar sakta hai.'],
#  ['@ Tweepshikha toh הי laga tumhari bhi shakel hogi usmein kahin: - /'],
#  ['my story ws totally opposite... maa mana karti thi n papa paise dete thhe... alwez... :)'],
#  ['@rynkee Kaho naaḩ hai'],
#  ['Aye Aye Captain'],
#  ['@ Alllahdin sab samajta hu main, Kabhi mein Kabhi Kabhi aisa ho jata hai'],
#  ['Itne to bhai wallet me chillar lekar chalte hai https://twitter.com/firstpost/status/603429262750691329'],
#  ["@ peacepiscean tumhare aashwasan Kejriwal jaise hote hai, hamesha disappointing < / 3: '("],
#  ['RT @khanakram421 : She : Bhaiyya – Chandi colour ka dress – Shopkeeper : Accha to tumhe Silver kameez –'],
#  ['jo jaisa dusro k Sath krta h uske Sath aisa hi hota h.. he cheated dada...'],
#  ['Modi ne #Notebandi toh kar di "par hamaare jaise #foreveralone engineers ke hÉireann bandi kab dhund dega 0 Kya yahi hai acche din?'],
#  ['Bhai kya bol raha hai https://twitter.com / iNeelSoni / status/654200935128895488'],
#  ['You can change the number of favorites by clicking on one of the buttons below.'],
#  ['agar woldcup jitna h na to.. sehwag aur yuvi ko bulale team me'],
#  ["@ BDUTT @ AmanKayamHai Grow up Bharkha... It's too much now. Bharat mai kahi shaktiman hai joo aaj Bhi problem mai hai... Whaha Jaa kar aao"],
#  ['@ balliawalebaba hahaha.. Ab aaye ho to kuch kam Bhi karlo'],
#  ['@ DefucktiveHumor pakistan jane to get your visa? Paagal mat ban'],
#  ['Daadhi badhao gandi shahl chupao. #JaagoGrahak'],
#  ['Sonia Gandhi has 90 per cent of the votes cast.'],
#  ['@ anjanasukhani Mandal Aabhari _ /\\ _'],
#  ['# GMT is The new Duckworth Lewis method'],
#  ['Porn mat dekha karo zyada'],
#  ['Auto main has?'],
#  ['# TripleTalaq sirji monkey ne to sab chura liya. triple "talaq ram" mandir "vikas appeasement opposition ko kucchh chhodo'],
#  ["Sir, can't wait fr #Bajrangi_bhaijaan <3"],
#  ['@ meetUunngLee'],
#  ['Toh chaabi kisne lagayi? Aur khoyi kisne?'],
#  ['Man Prashan Ho gaya Shkar.'],
#  ['Ghu mein pair Rakhoge toh dhona padega,ḩ mein padoge toh rona padega. # Irshaad'],
#  ['G1 to G2: Tera mera Bhri amar. Amar: Bhri tum dono pasand ho.'],
#  ['He cries and cries and cries becoz u wnt let him do it? Did you say you were seeing a\\ " guy\\"? ;)'],
#  ['@ Wyomnaut ohh.. Ye to andar ki baat hai.. Tumhe kaha se pata lagi?'],
#  ['Sabke saamne naak toh katwa hi deti hai biwiyahttps://twitter.com/anjanabhartia/status/887558772826152960'],
#  ['superr se uperrrrr (y) missng home'],
#  ['matlab 28 or 29 me se kis din aana hai..'],
#  ['kya baat hai!!guddu dher sa sa gags banana laga....:)'],
#  ['shubham teotia..iske number final me judenge..lol :)'],
#  ['Chalo ab koi sting operation karke kisi sarkar ko nanga Nahi kar sakti... maare jaoge # RightToPrivacy'],
#  ['@ justicearnab הי ab se gaaliya padne lagi hai: /'],
#  ['ATM me cash aane ka? https://twitter.com/CopyWalaTweet/status/803470605039255552'],
#  ['@ Beingakashss thanks bhai Tere Tweet Ka Wait Tha bhai'],
#  ['Yahan se ek suwar phenk kar maarenge, saara radicalism uttar jayega. https://twitter.com/defencepk/status/867363923770523649'],
#  ['Ye sab padhne se pehle meri aankhein kyun Nahi phoot gayihttps://twitter.com/meDigitalGanesh/status/868125471636164610'],
#  ['Kitne zor se diltoota hai tumhara?'],
#  ['Aap reply karenge....?'],
#  ['"Prabhu der aaye par durust aaye" This budget is a revolution in Modern Indian Railways.'],
#  ['@ Hindiplz @insane_chorri Allahabad se yaad aaya hum Allahpur / Alopibagh mein poora ek saal rahe the :)'],
#  ['@HITKPKD #LalHITMovies'],
#  ['30 of se continuously swimming pool ja raha hoon. Aur in ladkiyon ne ek Bhi din chhutti Nahi ki. Kal se band karna padega.'],
#  ['Bhaijaan kaha he aap?'],
#  ["I'm also against arrest of Tanmay Bhat, kaan pakad ke utthak -baithak karwa kar chhod dena hÉireann."],
#  ['Kuttey ki to kismat haihttps://twitter.com/iKunaal/status/699562516662214657'],
#  ['"Mein Kaun Banega Crorepati se Amitabh Bachchan bol raha hu.." SBI Employee: Ab to bank band hone ka time ho gaya. Kal phone karna..'],
#  ['@ akshaykanitkar Bajate Raho!! @ witchybitchygal'],
#  ['# WorldNoTobaccoDay issi baat par ek cigarette sulgao.'],
#  ['"Bhaiya ek Malai chicken kofta lana"'],
#  ['@ Jamuntini Oh ho. Aaj Ghaib.'],
#  ['Gauribee'],
#  ['only kejriwal... baki sab bakwass'],
#  ['Chota bachcha samajh ke humko na aankh dikhaana re.. - Arya Stark @ AndColorPockeT'],
#  ['Your emails'],
#  ['From "azaadi hi meri Dulhan hai" to "Mera toh kaam hi mera valentine hai"'],
#  ['@ MeetUunngLee sab'],
#  ['its Ch 97 99:34 tune galat bola.. ab to tu gaya'],
#  ['. @ sonakshisinha ladkdi ne dimaag wali baat kahi haipic.twitter.com/czDwKdvDaS'],
#  ['Bharat mata ki jaihttp://markmanson.net/a -dust - over -india'],
#  ["chota bheem new movie kab aayegi sir? can't wait"],
#  ['@ Lala_The_Don abb Bihar'],
#  ['@ KyaUkhaadLega @ zoomphatak kyu bhai? Kya sawaal puchna hai?'],
#  ['Haan, haan, haa, haa, haa.'],
#  ['Kal Modi ji Dubai se 4. 5 lakh crore le kar aaye.. Aaj Bihar ko 1. 25 de diya.. Ab bache 3. 25 lakh crore'],
#  ['Jis team ke paas aise top 4 ho, use baki ke 7 players bonus me kyu diye jaate hain! # RCBvDD'],
#  ['Your emails'],
#  ['@ GavriE01'],
#  ['Relationship Status: Ummeed par boner kaayam hai'],
#  ['Bas karo @awk_doc ji..'],
#  ['KABHI KABHI FRUSTRATE HO JATA HU'],
#  ['Error saving alarm calendar'],
#  ['Your emails'],
#  ['Bhai aapki ye movie chhappar far dega'],
#  ['Mere paapa tumhare mummy ko aisa dhe se bulaate hai. https://twitter.com/e29ad41b95b341d/status/697799527986655234'],
#  ['Uber? 2 minutes main a jayegi.'],
#  ['@iamGunjan'],
#  ['Kanoon ne plaque ka kabhi to teri terrorist titled ko maara. https://twitter.com/ANI_news/status/607822591085051904'],
#  ["when i teach a basketball in my own school, we're gonna spend the 1st day watching larry bird videos, &amp; the rest will take care of itself."],
#  ['# NitishKaNakliVikas'],
#  ['@ ImranKhanPTI #trump'],
#  ['@ ttrinadasgupta Aaila, bahar kyu Nahi'],
#  ['Hum khud sure Nahi hai "toh Kautilya ke baarein main kya kahe #GST #IndiaToday #TheHindu'],
#  ['@ Arunapk57 @ JustLikeMikee bilkul, magar baaki 90% logon ke hÉireann Nahi :-P'],
#  ['Lag rha hai aaj Rahul Gandhi Zimbabwe ka Support kr rhe the.'],
#  ['# MannKiBaat'],
#  ["@ fragrantica_ sarhadei 'n insaano ke hÉireann hain. Socho tumne aur maine. Kya paaya insaan hoke."],
#  ['"Waah kya hashtag hai" # GoonsOfNitishKumarpic.twitter.com/PrGQJpnyFC'],
#  ["@ Khushi_Ranbir But'Khushi' Zaroor use karna...... accha sound karta hai :-)"],
#  ['cc @ OfficeOfRG sir ladki kashmiri bramhin hai.. ek teer do shikaarhttps://twitter.com/NotMits/status/756488849027657729'],
#  ['@insane_chorri Adeeba... ye tune kya kya kya.. @narendramodi'],
#  ['"Mein tumhare хоног me Gadkari ji ke garden ki sabjiya kha sakta hu"'],
#  ['Bihar mein bahaar # BadliyeSarkarBadliyeBihar'],
#  ['@ WatDaDuck_ bhai jab se wo chhod ke gayee hai.. Tab se daru chhad hi Nahi rahi'],
#  ['RT @ayooshgupta: @ SanjayAzadSln @ AamAadmiParty HAHAHA..... ODD_EVEN NE TO JANTA KI HI LELI.. & SWARAJ BHI ACCHA MILA DILLI VALO KAO...'],
#  ['HAPPY MAHASHIVRATRI <3 JAI BHOLENATH <3 <3 JAI MAA PARVATI <3 http://t.co/xMhhsKrpBV #Hindus #Hinduism http://t.co/iNe3qJVdtL'],
#  ['Watching again #PCkumar at @abpnewstv'],
#  ['@ imcomplicated__ tum itne durr ho bhi dil ke paas ho.'],
#  ['@haranyashettyy Bura added jab Mecca Madina / Vatican se compare hota hai.. Kab tak tent house me rahenge Ram Lalla?? AAKHIR KABTAK??'],
#  ['cartoonist ne google se nikala hai prestige ka meaning'],
#  ['Once again. tu m wo add wali ladki ka number do " tu m @ hai wo Bhi # jio use kar rhi'],
#  ['Iski Bhi philum aa ri kya? https://twitter.com/minimathur/status/801025520070774785...'],
#  ['Gori teri aankhein kahein, raat bhar peeti rahi'],
#  ['@ Atheist_ Krishna hehee.. Bhai kidding.. Mast lag raha hai'],
#  ['@ Atheist_Krishna maine mere phone camera se nikala hai ye pic, Rajasthan :)'],
#  ['Qayamat Se Qayamat Tak me Aamir Khan aur Juhi Chawla ko хоног hua tha.. Kya hua?? Maare gaye na dono..pic.twitter.com/6KRmETQ74L'],
#  ['@ jnsbmi Modi ko gaali diye bina Nitish ji ka khana Kaise hazamkhwa unka # GoodByeNitishKumar'],
#  ['@ SwaggerBanno mere zakhmon par namkeen hona hi tha toh hothon se laga lete, waise Bhi chakna kam pad raha hai. # Irshaad'],
#  ['@ CoupSteer 3 saal ka anter accha swasth maa majbut baccha'],
#  ['Salman you r being human love you bby..'],
#  ['@ sanjaymanjrekar bhai 25 jagah bol chuke ho same baat'],
#  ['Damaad ki Bhi izzat Nahi ki. Intolerance is rising. # IndvsPak'],
#  ['@ Alllahdin Aashirwad banaye Rakhe _ /\\_'],
#  ['Good morning pitaji. Dhan Dhan Satguru Tera hi Aasra Need # BlessingsOfMSG'],
#  ['# TripleTalaq ke "baad"sir ab dahej ke against kuch kade kanoon "banaiye pls address this problem.'],
#  ['Koi benefit hai inko ye sab dikhane se????'],
#  ['Modi ji Hamara hindustan ka name get ucha Rakhna.jai bharat mata jai hind..'],
#  ['Sachin ke bina yeh world cup adhoora hai! :| # missYouSachin'],
#  ['Ab Kaun Karega Anhoni Ko Honi?'],
#  ['Enter the language you want to be translated into:'],
#  ['Deja Vu hai. Mark idhar thaa... Pichle saal Bhi.'],
#  ['Sir ek plate kajal pakode dena.'],
#  ['film ka story mast he aur aap Bhi mast ho..........'],
#  ['Bhai... Aap ki original voice nhi hai..'],
#  ['Share karo market mein naya aaya hai pic.twitter.com / MCDOsNu3Sr'],
#  ['@ LosingMotion'],
#  ['Adbudh Show from'],
#  ['@ MePurplelicious aur ek majnoo ghayal: p'],
#  ['kaun bole parents ko Nahi hai interest unke bete mein :d :d toh bekar mein kyun dekhousse'],
#  ['@ tweeting_pal matlab koi kuch Bhi nikal sakta hai, maine toh woh bilkul Nahi kaha'],
#  ['bhagwan aisi girlfriend sabi ko de.. par start'],
#  ['Don No. 1 to best hai:'],
#  ['you aaiyena naaa wala character you will find in every school and college'],
#  ['Bhai tu odd day pe Facebook Що kar aur even par LinkedIn https://twitter.com/Atheist_Krishna/status/682869864243974144...'],
#  ['gaali dena kam kar dia hai reputation, color ek badi wali zaroor deta, mauka bhi hai aur dastoor Bhi, chutiye bhare hai'],
#  ['Nice work brother, Hum sab me Gabbar hai!! ;) https://t.co/k2uvDXr0JJ'],
#  ['Hi @ bomanirani sir Apne kaha tha remind kradana Autograph send karna hai so please send kardo.'],
#  ['ohohoohooo.. is level pe aane kekhwa is saal ke end tak ruknakhwa'],
#  ['Tu theek hai na? Rulayega kya?'],
#  ['@ LoKarloUnfollow kararaΙΝ milega.. kararaΙΝ milega..'],
#  ['@ IScreamPunday'],
#  ['@ Nirmalogy kaisa hai bhai'],
#  ['Where sab theek hai magar tu kahan hai?'],
#  ['@ Nomnombiar Aisay Thorina hota hai'],
#  ['ye ek baar hi bolo kafi hai @isaifpatel'],
#  ['Sbi exited h k pakistan harega... aree ye koi nai baat h kya... # IndvsPak'],
#  ['I think you forgot to show song of Roja movie'],
#  ['. @ JhaSanjay chup ho jaa....pic.twitter.com/Jhf4egi9uo'],
#  ['RT @ 2806anu : @ pushpraj Challenge: Isse bura likh ke bataao'],
#  ["So if you think relationships are just about spending money.,.,. I am glad you don't have any Girlfriend.,., :P"],
#  ['Apne career ke Shikhar Dhawan par!!'],
#  ['ek baar toh guddu ko bhi chalaney detey.. ya idhar bhi pair Nahi pahunch rahe? :p'],
#  ['Raj Thackeray: Pay Rs. 5 crores Karan Johar: कभी ye humse ladta hai कभी jhagadta hai, koi paas iske na aana, ye ladka hai deewana.'],
#  ['where r uu...bhaiii...plzz one rplyy mustt onlyy onee: - ('],
#  ['Yaar surname badal kar Choonawala Rakh le. https://twitter.com/tehseenp/status/894906260943810560...'],
#  ['Salman bhai jai ho. Blessings to bajrangi bhaijann.....'],
#  ['Please enter the name of the email address you want to receive as soon as possible.'],
#  ['IshQ waLa || ~ ^Å\x81Ã ̧VÄ›^ ~ || â€“ listening to Ishq Wala Love ( From " Student of the Year " ) The DJ Suketu Lounge Mix'],
#  ['My ExRoomie & whenever I chk him on phone now. I remember " Raj, name to suna hi dhe " ( Yes https://t.co/xsQZqk8xDk https://t.co/R0lTcnQXKd'],
#  ['@ GaurangBhardwa1'],
#  ['Hamare paas fruits khareedne ki haisiyat hai, Zomato se khana order karte hai hum Rs. 400 ki, delivery boy ko Rs. 20.'],
#  ['Chicago: go see @ someUSER #lovesgotaholdonme #sat october 27th 7p at the # haroldwashingonculcntr 47th &amp'],
#  ['Believe na ho to wikipedia me Awards section padh le #ConfusionKaEnd #SRKDonates1crToChennai #ISupportDelhiOddEven https://t.co/eegdts4Kf8'],
#  ['Hi, I am a writer. Hafte bhar se ghar par paani Nahi aaya hai, aur dadaji ka jhola lekar ghom raha hu, koi vada paav khila do.'],
#  ['@ Singhlicious bas sab khairiyat :-)'],
#  ['@ Fuljhadii ka map'],
#  ['Misbah to Butler: Kuch acha sa khila do yaar, haar gaye! :( Shoaib Akhter: Tu Rehem Kha, Rehem.'],
#  ['@ PennyPurewal kaun hai?'],
#  ['@ twinitisha shahrukh ki movies Kabhi achi hoti hai?'],
#  ['Saadar pranaam. Su Prabhat!'],
#  ['Click here to view the current page.'],
#  ['dollar gains on euro amid greek woes: new york - the euro sagged against the dollar on thursday as the revised g.. http / URL'],
#  ['Ladki gori honidhā chahe ladke ki shahl koyle jaisi ho. Assholes.'],
#  ['Today: sefton v'],
#  ['Abhi to tum 18 ki Bhi Nahi hui thik se!'],
#  ['# IndvsPak Lagatar 6 #WC se TV todte aa rahe h hahahaha....'],
#  ['@ RoflGandhi_ Saralta'],
#  ['Bhai tu Marathi hai.. tu jaake sairat Dhu'],
#  ['4 baje meri college mein class hai bhai jaaan :('],
#  ['@ sonisinghall lag raha* hai'],
#  ["Let the good times roll! tomorrow is Tuesdays gras at st. philip's, with the bob deangelis dixieland band and gumbo lunch. join us at 10:30!"],
#  ['"Hum Laye Hain Toofan Se Kashti Nikal Ke" - Modi "Hum to wapas toofan me le jaenge" - Shatru #BiharKaJaichandShatrughan'],
#  ['thanx salman bhai..love u forever'],
#  ['guddu india ka lucky charm hai: d'],
#  ['# 341: Best part of the placement orientation was that hot Matki Chick. Really wanna hook up with her. Suggest a way.'],
#  ['inhe kaho hindi hi theek hai.. aise to guddu ki english aur bigad jayegi : d'],
#  ['Ankhon hi ankhon mein ishaara bhoya, baithe baithe FIR ka sahara bhoya?'],
#  ['@ jhunjhunwala Main be - Car Nahi hoon aise hi mat Thoko kuch Bhi @ indiantweeter'],
#  ['@ sunny_ congress # are waah!!..... dharti maa ka yaad... supperb tu sawa sher h'],
#  ['Apake upar bharosa hai....bhai! Aap koi galat kam nai karhesh....'],
#  ['@ owl_baba Bhai wo i6khwa @kitAnurag'],
#  ['wagh bakri chai is though. Add with chaayos Adrak Tulsi.'],
#  ['Koi accha contest b Nahi jab free hote'],
#  ['@ PushprajZala NO, SOCH SAMJH KE KIYA KAR. KABHI VOTE NAHI KIYA ELECTION ME?'],
#  ['@ LoKarDi_RT LOL! bura laga? Sorry ok? But table aur chair ki fikrr karni hÉireann, adkki mil jaaye toh kaam aayega!'],
#  ['ha ha nain aisa kuch nahin hai :)'],
#  ['@ tweetingsourav bete jis tarah susu ka koi time Nahi hota.. Waise hi sly ka koi time Nahi hota'],
#  ['Meanwhile Faridabadi, ah! Daily ka routine h, aaj jogging karte hue jaunga.'],
#  ['@haranyashettyy kuch bhi chalega @sunandavashisht @ask0704'],
#  ['damn. I thought I was the onlu one who did this :)'],
#  ['# surgicalstrikes worldn ne loha mana hai. gadaro aur deshdrohio ki tolly me hahakar hai. Aur dusman muh chipa kar dar se saham gaya hai.'],
#  ['I paid tweet karne hai, shaadi ke paise ikatthe karne hai.'],
#  ['aww my daddy is best too.. i love my paa.. :)'],
#  ['RT @usha_khokhar: Pakistan to Twitter'],
#  ['NaMo - mere paas sarkar hai, pin stripe suit hai, india ke development ke plans hai. Tere paas kya hai? RaGa : mere paas holiday hai # WhereIsRahul'],
#  ['Playing'],
#  ['@ itdhruvism bhai aapne be j jan'],
#  ['Chalo koi na hota hai, ladkon ko aise aage ruka kar mat Rakhna. Ok?'],
#  ['@vikrantkumar yahi hota hai :)'],
#  ['.......................'],
#  ['@ AnubhaShukla7 wo to malyali hai :)'],
#  ['@ Insane_chorri bas maja ma. Khushi ke aansu aa rahe hai'],
#  ['@ anuradha_kush Nakaam mohabbat ki aag main jal rahi mahila aur yeh aashiq number 2'],
#  ['Friday night hai, beer piyo apne aansoo Nahi.'],
#  ['Choot ko kejri se compare karke choot ko gaali na de'],
#  ['319 Run To Bante Dikh Nai Rahe The..'],
#  ['hey bajrangbali bas aaj ek reply mil jaye..'],
#  ['Koun kahta hai modi ji kam Nahi kar rahe 4 mahine mein hi # Trump ka replica bana diya.... # YogiAdityanath'],
#  ['harry redknapp 2nd favourite at 7/4 to be next blackburn boss!! venkys please make this happen!!! #makeredknapparover'],
#  ['ab to tu aajkal pata Nahi kaha gayab rehta hai'],
#  ['Suna hai @ BolshoyBooze ki shaadi hone wali hai. Kitne Dil productnge?'],
#  ['Salman ji apka favorite gAna konsa hai bajrangi bhaijan film ka?????'],
#  ['ye ketu aur Rajdeep Rahu? @ sagarikaghose'],
#  ['Ambuja cement se chipka do guduu ko..'],
#  ['Dil mein apne Monday ka darr lekar jaage ho, toh zinda ho tum.'],
#  ['@ Fussy_Ca abe 3000 me lee hai maine'],
#  ['@ Atheist_Krishna eet ka hÉireann pathar sepic.twitter.com / Zktq0SzqmO'],
#  ['RT @ MehakTweets_ : Gets up. Voice from the lounge " Aur dekho aik aur supporter jaag gyi hai " ðŸTM„ðŸTM„ðŸTM„'],
#  ['jb pehle hi pta hai ki ye tingu lofer hai.. :d'],
#  ['Baby ko sirf nalayak haramkhor ladke hi pasand hai.'],
#  ['yea.. i can not disagree with the confession..... and yes... i was among the exceptions..'],
#  ['Bhai iftaar farty hai kya?'],
#  ['@ Chaitanya_13 ludo. Kahan hai aajkal?'],
#  ['lol, ye kya hai?!'],
#  ['https://twitter.com/anandvasu/status/846617515295830022...'],
#  ['Your emails'],
#  ['ye sonia ji ki bahu hai'],
#  ['"AAP jaisa koi mere zväč mein aaye toh jhand ho jaaye" - Delhi Chaps'],
#  ['Leaving chalk laya kaha se?'],
#  ['To ye tere chacha nekhwa hai?'],
#  ['garbage.. yaar tussi har bar dil jeet lete ho kasam se.. kya mast reality har bar saamne late ho... besi saari harkate yaad aa jati hai : p : d'],
#  ['JUG soona soona laage - Sonam Kapoor'],
#  ['Silent Message for all of you guys,,,,,,,, Hahhahaha'],
#  ['RT @ ShivAroor: Anyone care? The 3 Army jawans ambushed, killed by NSCN terrorists in Arunachal Pradesh today: Sanjiv Kumar Parmal Singh Guj'],
#  ['# ManmohanSingh mode on chale gaye hain'],
#  ['Police peecha kar rahi mera.. pic.twitter.com/RZVL9FUV03'],
#  ['@ JrYoungmonk'],
#  ['kisi ne Bhi sweter kyu Nahi pahna h itni sardi me?? :o'],
#  ['Not joking sach much taras aata hai'],
#  ['. @ MehrTarar bhabhi India me aapke saare dewar aapko yaad kar rahe hai..'],
#  ['@ friendlii_ ghost kab. Bataya Bhi Nahi'],
#  ['#NitishKaNakliVikas'],
#  ['Ghaseet ghaseet kar leke jao sabko Snapchat par, waise Bhi Twitter zyada hi bhar gaya hai.'],
#  ['@ MeetUunngLee hurt you? Nahin bhai aap stud hai'],
#  ['Bahot zor se food blogger banna hai, khaane peene ke vaande hai.'],
#  ['yaar itna dhaansoo humor kaha se late ho...'],
#  ['@riksec08 # CrackerNACrackKAR bolne wale ki baat mat sun'],
#  ['o... bc.... bhai purani saari yadein taaza karr di rofl!'],
#  ['Iss Kanhaiya ko apni bansuri par control Nahi hai https://twitter.com/NewsX/status/707893915085443073...'],
#  ['Original power dil me hoti hai'],
#  ['ab south africa me bhi shop ke bhar # bika_hua_wapis_nhi_hoge ka board ltga hai.... # IndvsSA shabash shero................ make us proud.....'],
#  ['@ TheTopiWriter @ AdvancedMaushi'],
#  ['To bhai SRK ka target audience India hai ya UAE.. Agli film Dubai me release hogi to tu kaise dekhege https://twitter.com/SRKswarrior1/status/678074882379423744...'],
#  ['Aur #RahulGandhi ji ne apni hi Party @ INCIndia aur apne pariwar k itne saalon k is محاصر par ek aur #SelfGoal kar diya...'],
#  ['#trump must be so envious of #kejriwal.'],
#  ['@ YearOfRat batao aap, kahan milna hai?'],
#  ['Your emails'],
#  ['i totaly agree with the post.. teachers have no right to spoil students Carrer now...'],
#  ['@rahulroushan Dosti bani rahe'],
#  ['Sena se # SurgicalStrike ke proof maangne wale pakistan premi # ArvindKejriwal deshdrohi hain. twitter. com / xX 7 W 3 kC 0 Tu'],
#  ['Superb again!! Line mat kaato kutton, aap Qatar mein Hai. https://twitter.com/hankypanty/status/895235287579865088...'],
#  ['@clued_up_chic abhi baaki hai mere ghost'],
#  ['RT @ aryaraju: As per Rajmala, the royal chronology of Tripura, a total of 184 kings ruled over the state.'],
#  ['endymion for the 4th time i blieve'],
#  ['guddu ab... young ho raha h..'],
#  ['Ghar main Agarbatti din main do baar use hoti hai. Pooja important hai but "Pooja" Archana Sadhana etc Nahi.'],
#  ['@Mohit_JNU @Shehla_Rashid @UmarKhalidJNU @kanhaiyajnusu aur tum log maza le rahe hai 0 Student #JNU ka protest kar rahe #AMU 0 wah wah wah wah'],
#  ['Tu bhai state mein "rape violence rok. Haryana ki durdasha kar di hai. Film bada issue nhi hai murkh. Bada Deshbhakti ka tekhedar bna hai.'],
#  ['@jalanpurvi @ StarMoviesIndia'],
#  ['Yaha ₹5 se lekar ₹500, sab chalte hain. Chhutte ki tension mat karo, bus Paytm karo.pic.twitter.com/1iaRdjOeoi'],
#  ['baap bda na, Bhiya, sbse bda rupaiya h aj k הי.....'],
#  ['@ indiantweeter'],
#  ['Sir Jee Himmat Agar Itna He Hai to # Reservation Hatayiye... # Demonetization aur # GST to Koi Bhi Kar Sakta Hai..'],
#  ['Kareena: Kaun hai woh jisne הי dobara palat kar Nahi dekha? Sony TV: Anoop Soni'],
#  ['. @ brownbrumby jaa bhai sawari dhoond.. @ BinaKaheLunga'],
#  ['excited about the bump in ram for raspberry pi'],
#  ['Trai ko kya problem Hai jab koi free de Raha Hai #jio #airtel'],
#  ['Dil dhak dhak karne laga.. mora jiyara darne laga.. https://twitter.com/Coolestvibe/status/780083496656117760/photo/1pic.twitter.com/CSwEaTINjQ'],
#  ['@ manish239994 AC'],
#  ['paise dene ki baat hi Nahi rahi, bas khana khila do (in lines to my original tweet) :-)'],
#  ['@iamsrk @Varun_dvn @kritisanon Shah ka ek comment aur media walle peeche bhaage, waise hee mere manwa mai emotions jaage ;)'],
#  ['Arey bhai pm ho.. desh ko ullu mat banao!'],
#  ['@ akshaykanitkar @ RoflGandhi_ ye to prasad bhi leke aayakhwa'],
#  ['@ HiighBeta aaj vrat Rakha hai?'],
#  ['@NeetuGarg6 @ArjunIrplast @RitaG74 @YouTube'],
#  ['@ SRKswarrior1 maine jaaneman bdekhi thi Don Nahi'],
#  ['Agar aur ek meeting ho gayi toh recession Bhi sabse pehle aa jaega. # GST'],
#  ['Accha hua packet pe chips likh diya varna pata hi nhi chalta kya kha raha h udbilau..'],
#  ['Thank you very much'],
#  ['@ SharmaJaungi @ SlapSkirt'],
#  ['RT @ Iam_ Prerna: Ye nalayak out Bhi honge aur gaaliyan Bhi khayenge # IndvsPak'],
#  ['So @ muglikar_ ko economist banana tha isliye modiji ne desh ko gareeb banaya. Ab samza # DeMonetisation aur # GST ka game'],
#  ['I went to college, and I said, laddu k jgh pedha.'],
#  ['@ YearOfRat best part hai woh, likhna sach mein Bhi ulta hi chahta hai woh dikh jayega, tweets mein zyada badlaav Nahi honge'],
#  ['RT @shankarshanmugh: 2 - with Kenny bates action producer and Nirav Shah DOP at Nehru stadium Delhi. https://t.co/9wTHvU9SLm'],
#  ['@KajuBadamChor Galli galli meinĦta hai tu kyun ban ke banjaara????'],
#  ['Haatim Tai ka beta lag raha hai https://twitter.com/firstpost/status/775576636766973952...'],
#  ['RightToPrivacy'],
#  ['Ye mera gaon hai aur main is gaon ka Singham # Ranchipic.twitter.com / Au5l2xMcV9'],
#  ['See the level of people doing phd, i dnt know wat shit they will teach to students?'],
#  ['Janta ne es jeet se dekha diya ha # GST # Demonetisation safal ha. Opposition ne bht koshish ki par asafal rhe. Ab Gujrat aur Himachal Bhi aase he jeetenge'],
#  ['@ Shahrcasm'],
#  ['@ GabbarSingh shaadi main jyada kuch aaya Nahi. Car Bhi maruti di hai.'],
#  ['Dus bahaane kar ke bharwa di bill.'],
#  ['Thank you sir...umeed karta hun meri face se aapko koi dost nahin ganwana padega'],
#  ['My Bhi koi book me jagah de do. https://twitter.com/ANI_news/status/627686121086955520...'],
#  ['Bajrangi Bhaijaan kitni baar dekhi'],
#  ['You Bhi theek kahan hai tumne mohtarma!'],
#  ['Saale mere kandhe pe Rakh kar bandook mat chalao'],
#  ['Yeh sab # Trump ki face se ho raha hai 0 # INDvsAUS'],
#  ['Ek dooni do, do dooni char Kar do #LaluMuktBihar #MDL'],
#  ['mere pass ye 2013 wala bhi hai https://twitter.com/BolshoyBooze/status/310644632805576705...'],
#  ['# GoodAdviceIn4Words "Chaar log kya kahenge" - Indians'],
#  ['Virat bhai congrats for winning again against Pak. bharat mata ki jai'],
#  ['@ sonakshisinha bhai @ indiantweeter ab tu compatriot account bana ke sona ko pareshan karega!!!'],
#  ['Kamaal map ho Salman ji aayeh Bhi Nahi..'],
#  ['@ Marut_ kyonko agar ye 100% bolenge to log sochenge ki ye jhooth bol rahe hain, isliye 99.99 lol'],
#  ['iske bina to jeewan adhura tha'],
#  ['@ HaramiParindey Hahaha.. kaafi Ojaskhwaya tha'],
#  ['Tumhara 4G, Vodafone 4G, saala 2 milta hi Nahi.'],
#  ['@ vivekisms acche from aa gaye @dhaval241086'],
#  ['agar ne is class me hoti to kissi b boy ko top na karnr deti.. isme b toper me hi hoti.... :d'],
#  ['@dhaval241086 Ye AAPtards ki harkat hai!! @wistyloony @witchybitchygal @SatanKiNani'],
#  ['@ Ashkaikini yaar, please yaar Ashwini. Chal daaru peete hai'],
#  ['@ Inkoo New York!'],
#  ['Yes man but plaque gujaara Nahi hai is chalaak world mein'],
#  ['Usne bola aapne maan liya. Kapil sharma ne proof diya aapko aur chaiye. Army ne # surgerystrike ki apko saboot chaiye. U need break'],
#  ['@ DrKumarVishwas @indiaaakash අද ki உலகம் koi imandar Nahi hai. Jo khud kahta hai wo sabse bad a chor hai.'],
#  ['Koi Bhi colony mein ghosna ho toh saale puchte hai kahan jaoge? Tell them a random number, B-25 ya G - 305, ye jaane denge andar'],
#  ['No change in team hum to batting hi karege'],
#  ["Bhaiyoooo plaquey plaquey kaam kerlo... history won 't be changed...."],
#  ['. @ angryoungwoman shakehari hone kekhwaro ko bhi shakehaari kare.. Aur haan kal Yoga zaroor kare..'],
#  ['@arunjaitley service tax badha diya sir?? Chalo jaise aap chaho!!!'],
#  ['Yeh Dhoni KL Rahul ko century Nahi banana dega.'],
#  ['@ lady_naarad ohh regarding laga aapki ho chuki hai'],
#  ['grt step 4grt relation...nic job sir'],
#  ['@ SandSurfer @ ghost_particle'],
#  ['Ab Bihar me aayegi bahaar'],
#  ['RT @ Shindekar: Shikher well played 100 not out.. gabbar abhi thokho... # IndvsSA'],
#  ['Ab kya Muqein, Bhediyon par vishwas kya ja raha hai, vishwasghaaat tohkhwa.'],
#  ['@ someUSER hell yea lmfaoo, &amp; see you tomorrow asia baby (;']]

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (1.21.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (0.8.10)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from sacrebleu) (4.9.2)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.7.0 sacrebleu-2.3.1

# %%
ans= []
for i in ans_list:
  ans.append(i[0].lower())

# %%
truth = []
ground_truth = target_sentences[:765]
for item in ground_truth:
  truth.append(item.lower())

# %%
from sacrebleu.metrics import BLEU
bleu = BLEU()
result = bleu.corpus_score(ans, truth)
print(result)
# Out:
# BLEU = 2.17 13.0/2.3/1.2/0.6 (BP = 1.000 ratio = 23.000 hyp_len = 23 ref_len = 1)
